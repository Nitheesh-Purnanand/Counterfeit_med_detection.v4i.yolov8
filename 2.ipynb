# %%
import os

base_path = "."

splits = ["train", "valid", "test"]

for split in splits:
    img_path = os.path.join(base_path, split, "images")
    lbl_path = os.path.join(base_path, split, "labels")
    
    num_images = len(os.listdir(img_path))
    num_labels = len(os.listdir(lbl_path))
    
    print(f"{split.upper()}:")
    print(f"  Images: {num_images}")
    print(f"  Labels: {num_labels}")
    print("-" * 30)
# Out:
# TRAIN:
#   Images: 4072
#   Labels: 4072
# ------------------------------
# VALID:
#   Images: 122
#   Labels: 122
# ------------------------------
# TEST:
#   Images: 65
#   Labels: 65
# ------------------------------

# %%
from collections import Counter

label_dir = "train/labels"
counter = Counter()

for file in os.listdir(label_dir):
    with open(os.path.join(label_dir, file), "r") as f:
        for line in f.readlines():
            class_id = line.split()[0]
            counter[class_id] += 1

print("Class distribution in TRAIN:")
print(counter)
# Out:
# Class distribution in TRAIN:
# Counter({'0': 6696, '1': 567})

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="data.yaml",
    epochs=10,        # small test
    imgsz=416,       # reduce image size
    batch=4,         # reduce batch
    workers=0        # avoid RAM overload
)
# Out:
# Ultralytics 8.4.15  Python-3.14.3 torch-2.10.0+cpu CPU (AMD Ryzen 7 7840HS w/ Radeon 780M Graphics)
# ...

# %%
import os
print(os.listdir("runs/detect/train"))
# Out:
# ['args.yaml', 'labels.jpg', 'weights']

# %%
import os
print(os.listdir("runs/detect/train13/weights"))
# Out:
# ['best.pt', 'last.pt']

# %%
model.val(data="data.yaml")
# Out:
# Ultralytics 8.4.15  Python-3.14.3 torch-2.10.0+cpu CPU (AMD Ryzen 7 7840HS w/ Radeon 780M Graphics)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 190.441.0 MB/s, size: 41.5 KB)
# val: Scanning D:\research papers\jenil_sir_project\Counterfeit_med_detection.v4i.yolov8\valid\labels.cache... 122 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 122/122 20.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.6it/s 4.9s0.7ss
#                    all        122        240       0.77      0.823      0.877      0.675
#              authentic        110        184      0.753      0.913      0.916      0.717
#            counterfeit         15         56      0.787      0.732      0.838      0.633
# Speed: 0.4ms preprocess, 29.7ms inference, 0.0ms loss, 0.5ms postprocess per image
# ...

# %%
from ultralytics import YOLO
import os

model = YOLO("runs/detect/train13/weights/best.pt")

# TRAIN
model.predict(
    source="train/images",
    save_crop=True,
    name="crops_train",
    conf=0.25
)

# VALID
model.predict(
    source="valid/images",
    save_crop=True,
    name="crops_valid",
    conf=0.25
)

# TEST
model.predict(
    source="test/images",
    save_crop=True,
    name="crops_test",
    conf=0.25
)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/4072 d:\research papers\jenil_sir_project\Counterfeit_med_detection.v4i.yolov8\train\images\109118801_3244498252272873_7164080379624931851_n_jpg.rf.272e6f3e15ce8f684d33af1920ff3617.jpg: 416x416 6 counterfeits, 36.9ms
# ...

# %%
results = model.val()
print(results.results_dict)
# Out:
# Ultralytics 8.4.15  Python-3.14.3 torch-2.10.0+cpu CPU (AMD Ryzen 7 7840HS w/ Radeon 780M Graphics)
# val: Fast image access  (ping: 0.30.1 ms, read: 3.01.3 MB/s, size: 48.3 KB)
# val: Scanning D:\research papers\jenil_sir_project\Counterfeit_med_detection.v4i.yolov8\valid\labels.cache... 122 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 122/122 157.1Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.2it/s 6.5s0.8ss
#                    all        122        240      0.721      0.855      0.809       0.63
#              authentic        110        184      0.837      0.924      0.959      0.777
#            counterfeit         15         56      0.604      0.786       0.66      0.484
# Speed: 0.6ms preprocess, 29.0ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to D:\research papers\jenil_sir_project\Counterfeit_med_detection.v4i.yolov8\runs\detect\val7
# ...

# %%
import os
import cv2
import numpy as np
import pandas as pd

# Path to cropped images
base_path = "runs/detect/crops_train/crops"

data = []

for class_name in os.listdir(base_path):
    class_path = os.path.join(base_path, class_name)
    
    for img_file in os.listdir(class_path):
        img_path = os.path.join(class_path, img_file)
        
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Mean and Std for each channel
        mean = np.mean(img, axis=(0,1))
        std = np.std(img, axis=(0,1))
        
        features = [
            mean[0], mean[1], mean[2],   # R, G, B mean
            std[0], std[1], std[2],      # R, G, B std
        ]
        
        label = 0 if class_name == "authentic" else 1
        
        data.append(features + [label])

# Create DataFrame
columns = [
    "mean_R", "mean_G", "mean_B",
    "std_R", "std_G", "std_B",
    "label"
]

df_train = pd.DataFrame(data, columns=columns)

df_train.head()
# Out:
#        mean_R      mean_G      mean_B      std_R      std_G      std_B  label
# 0  165.537308  157.422370  151.679617  67.243783  76.557730  76.903178      0
# 1  173.706477  171.444073  160.501374  61.571259  62.022496  65.662154      0
# 2  155.764483  150.428218  142.869940  58.082626  63.396733  70.191645      0
# 3  146.495541  141.184268  133.994985  61.219778  66.778094  72.502819      0
# 4  207.717167  190.215065  132.335786  42.585231  53.738962  79.296688      0

# %%
import os
import cv2
import numpy as np
import pandas as pd

# Path to cropped images
base_path = "runs/detect/crops_test/crops"

data = []

for class_name in os.listdir(base_path):
    class_path = os.path.join(base_path, class_name)
    
    for img_file in os.listdir(class_path):
        img_path = os.path.join(class_path, img_file)
        
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Mean and Std for each channel
        mean = np.mean(img, axis=(0,1))
        std = np.std(img, axis=(0,1))
        
        features = [
            mean[0], mean[1], mean[2],   # R, G, B mean
            std[0], std[1], std[2],      # R, G, B std
        ]
        
        label = 0 if class_name == "authentic" else 1
        
        data.append(features + [label])

# Create DataFrame
columns = [
    "mean_R", "mean_G", "mean_B",
    "std_R", "std_G", "std_B",
    "label"
]

df_test = pd.DataFrame(data, columns=columns)

df_test.head()
# Out:
#        mean_R      mean_G      mean_B      std_R      std_G      std_B  label
# 0  211.376186  216.367069  211.352771  61.684148  41.691629  39.787575      0
# 1  238.242563  105.953514   92.677703  27.738769  89.350810  95.865120      0
# 2  198.129320  193.847729  193.873910  50.596560  50.836713  43.366479      0
# 3  241.309263  100.098466   85.961757  27.362277  92.119623  99.884476      0
# 4  171.794535  160.475092  147.244912  55.189320  59.090234  68.215390      0

# %%
from skimage.feature import graycomatrix, graycoprops
import os
import cv2
import pandas as pd

# ================= TRAIN TEXTURE =================
base_path = "runs/detect/crops_train/crops"

texture_data = []

for class_name in os.listdir(base_path):
    class_path = os.path.join(base_path, class_name)
    
    for img_file in os.listdir(class_path):
        img_path = os.path.join(class_path, img_file)
        
        img = cv2.imread(img_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        gray = cv2.resize(gray, (256, 256))
        
        glcm = graycomatrix(gray, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
        
        contrast = graycoprops(glcm, 'contrast')[0, 0]
        energy = graycoprops(glcm, 'energy')[0, 0]
        homogeneity = graycoprops(glcm, 'homogeneity')[0, 0]
        correlation = graycoprops(glcm, 'correlation')[0, 0]
        
        label = 0 if class_name == "authentic" else 1
        
        texture_data.append([contrast, energy, homogeneity, correlation, label])

texture_train = pd.DataFrame(texture_data, columns=["contrast","energy","homogeneity","correlation","label"])


# ================= TEST TEXTURE =================
base_path = "runs/detect/crops_test/crops"

texture_data = []

for class_name in os.listdir(base_path):
    class_path = os.path.join(base_path, class_name)
    
    for img_file in os.listdir(class_path):
        img_path = os.path.join(class_path, img_file)
        
        img = cv2.imread(img_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        gray = cv2.resize(gray, (256, 256))
        
        glcm = graycomatrix(gray, distances=[1], angles=[0], levels=256, symmetric=True, normed=True)
        
        contrast = graycoprops(glcm, 'contrast')[0, 0]
        energy = graycoprops(glcm, 'energy')[0, 0]
        homogeneity = graycoprops(glcm, 'homogeneity')[0, 0]
        correlation = graycoprops(glcm, 'correlation')[0, 0]
        
        label = 0 if class_name == "authentic" else 1
        
        texture_data.append([contrast, energy, homogeneity, correlation, label])

texture_test = pd.DataFrame(texture_data, columns=["contrast","energy","homogeneity","correlation","label"])

# %%
import os
import cv2
import pandas as pd

# ================= TRAIN SHAPE =================
base_path = "runs/detect/crops_train/crops"

shape_data = []

for class_name in os.listdir(base_path):
    class_path = os.path.join(base_path, class_name)
    
    for img_file in os.listdir(class_path):
        img_path = os.path.join(class_path, img_file)
        
        img = cv2.imread(img_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        _, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        if len(contours) > 0:
            cnt = max(contours, key=cv2.contourArea)
            area = cv2.contourArea(cnt)
            perimeter = cv2.arcLength(cnt, True)
            x, y, w, h = cv2.boundingRect(cnt)
            aspect_ratio = float(w) / h if h != 0 else 0
        else:
            area = 0
            perimeter = 0
            aspect_ratio = 0
        
        label = 0 if class_name == "authentic" else 1
        
        shape_data.append([area, perimeter, aspect_ratio, label])

shape_train = pd.DataFrame(shape_data, columns=["area","perimeter","aspect_ratio","label"])


# ================= TEST SHAPE =================
base_path = "runs/detect/crops_test/crops"

shape_data = []

for class_name in os.listdir(base_path):
    class_path = os.path.join(base_path, class_name)
    
    for img_file in os.listdir(class_path):
        img_path = os.path.join(class_path, img_file)
        
        img = cv2.imread(img_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        _, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        if len(contours) > 0:
            cnt = max(contours, key=cv2.contourArea)
            area = cv2.contourArea(cnt)
            perimeter = cv2.arcLength(cnt, True)
            x, y, w, h = cv2.boundingRect(cnt)
            aspect_ratio = float(w) / h if h != 0 else 0
        else:
            area = 0
            perimeter = 0
            aspect_ratio = 0
        
        label = 0 if class_name == "authentic" else 1
        
        shape_data.append([area, perimeter, aspect_ratio, label])

shape_test = pd.DataFrame(shape_data, columns=["area","perimeter","aspect_ratio","label"])

# %%
# ================= FINAL TRAIN =================
final_train_df = pd.concat(
    [df_train.drop(columns=["label"]),
     texture_train.drop(columns=["label"]),
     shape_train.drop(columns=["label"]),
     df_train["label"]],
    axis=1
)

# ================= FINAL TEST =================
final_test_df = pd.concat(
    [df_test.drop(columns=["label"]),
     texture_test.drop(columns=["label"]),
     shape_test.drop(columns=["label"]),
     df_test["label"]],
    axis=1
)

print(final_train_df.head())
print(final_test_df.head())
# Out:
#        mean_R      mean_G      mean_B      std_R      std_G      std_B  \
# 0  165.537308  157.422370  151.679617  67.243783  76.557730  76.903178
# 1  173.706477  171.444073  160.501374  61.571259  62.022496  65.662154
# 2  155.764483  150.428218  142.869940  58.082626  63.396733  70.191645
# 3  146.495541  141.184268  133.994985  61.219778  66.778094  72.502819
# 4  207.717167  190.215065  132.335786  42.585231  53.738962  79.296688
#
#      contrast    energy  homogeneity  correlation     area    perimeter  \
# 0   50.951057  0.080443     0.383521     0.995102    544.5    98.669047
# 1   77.594868  0.063993     0.291203     0.989483  17720.5  1023.761534
# 2  148.684467  0.117271     0.526677     0.979262  56716.5   969.438599
# 3  155.897411  0.118840     0.523561     0.980502  56746.5   970.267026
# 4   15.552344  0.104274     0.539586     0.997120   7903.5   512.551296
#
#    aspect_ratio  label
# 0      1.590909      0
# 1      0.384615      0
# 2      0.967611      0
# ...

# %%
print("Total samples:", len(final_train_df))
print("Total features (including label):", final_train_df.shape[1])
# Out:
# Total samples: 8322
# Total features (including label): 14

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Separate features and label
X = final_train_df.drop(columns=["label"])
y = final_train_df["label"]

# Train-test split (important)
# TRAIN DATA
X_train = final_train_df.drop(columns=["label"])
y_train = final_train_df["label"]

# TEST DATA
X_test = final_test_df.drop(columns=["label"])
y_test = final_test_df["label"]

# Normalize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Training samples:", X_train_scaled.shape) 
print("Testing samples:", X_test_scaled.shape)

print("Train samples:", len(final_train_df))
print("Test samples:", len(final_test_df))
# Out:
# Training samples: (8322, 13)
# Testing samples: (180, 13)
# Train samples: 8322
# Test samples: 180

# %%
print(final_train_df.shape)
print(final_test_df.shape)
# Out:
# (8322, 14)
# (180, 14)

# %%
print(final_train_df.head(2))
print(final_test_df.head(2))
# Out:
#        mean_R      mean_G      mean_B      std_R      std_G      std_B  \
# 0  165.537308  157.422370  151.679617  67.243783  76.557730  76.903178
# 1  173.706477  171.444073  160.501374  61.571259  62.022496  65.662154
#
#     contrast    energy  homogeneity  correlation     area    perimeter  \
# 0  50.951057  0.080443     0.383521     0.995102    544.5    98.669047
# 1  77.594868  0.063993     0.291203     0.989483  17720.5  1023.761534
#
#    aspect_ratio  label
# 0      1.590909      0
# 1      0.384615      0
#        mean_R      mean_G      mean_B      std_R      std_G      std_B  \
# 0  211.376186  216.367069  211.352771  61.684148  41.691629  39.787575
# 1  238.242563  105.953514   92.677703  27.738769  89.350810  95.865120
#
#       contrast    energy  homogeneity  correlation      area    perimeter  \
# 0   321.098560  0.160001     0.573459     0.920182    6239.5  1016.409161
# 1  1100.912531  0.193354     0.418631     0.868909  118449.0  1800.274166
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# ================= SPLIT =================
X_train = final_train_df.drop(columns=["label"])
y_train = final_train_df["label"]

X_test = final_test_df.drop(columns=["label"])
y_test = final_test_df["label"]

# ================= SCALE =================
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# ================= MODEL =================
model = RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    min_samples_split=5,
    class_weight={0:1, 1:2},  # 🔥 increase weight for counterfeit
    random_state=42
)
model.fit(X_train_scaled, y_train)

# ================= PREDICT =================
y_pred = model.predict(X_test_scaled)

# ================= RESULTS =================
print("Classification Report:\n")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87       119
#            1       0.78      0.66      0.71        61
#
#     accuracy                           0.82       180
#    macro avg       0.81      0.78      0.79       180
# weighted avg       0.82      0.82      0.82       180
#
#
# Confusion Matrix:
#
# [[108  11]
#  [ 21  40]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Create SVM model
svm_model = SVC(
    kernel='rbf',
    C=5,                     # ↓ reduce overfitting
    gamma=0.1,               # 🔥 more flexible boundary
    class_weight={0:1, 1:2}, # 🔥 push counterfeit detection
    probability=True         # needed for next improvement
)

# Train
svm_model.fit(X_train_scaled, y_train)

# Predict
y_pred = svm_model.predict(X_test_scaled)

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8555555555555555
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.89       119
#            1       0.77      0.82      0.79        61
#
#     accuracy                           0.86       180
#    macro avg       0.84      0.85      0.84       180
# weighted avg       0.86      0.86      0.86       180
#
#
# Confusion Matrix:
#
# [[104  15]
#  [ 11  50]]

# %%
import joblib

joblib.dump(svm_model, "svm_model.pkl")
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(
    n_estimators=500,        # more trees
    max_depth=5,             # prevent overfit
    learning_rate=0.03,      # slower learning = better
    scale_pos_weight=8,      # 🔥 push counterfeit detection
    subsample=0.9,
    colsample_bytree=0.9,
    random_state=42
)

xgb_model.fit(X_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
import cv2
import numpy as np
import joblib
from ultralytics import YOLO
from skimage.feature import graycomatrix, graycoprops

# -----------------------------
# Load trained models
# -----------------------------
yolo_model = YOLO("runs/detect/train13/weights/best.pt")
svm_model = joblib.load("svm_model.pkl")
scaler = joblib.load("scaler.pkl")

# -----------------------------
# Function to extract features
# -----------------------------
def extract_features(img):

    # ----- COLOR FEATURES -----
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    mean = np.mean(img_rgb, axis=(0,1))
    std = np.std(img_rgb, axis=(0,1))

    # ----- TEXTURE FEATURES -----
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, (256, 256))

    glcm = graycomatrix(gray,
                        distances=[1],
                        angles=[0],
                        levels=256,
                        symmetric=True,
                        normed=True)

    contrast = graycoprops(glcm, 'contrast')[0, 0]
    energy = graycoprops(glcm, 'energy')[0, 0]
    homogeneity = graycoprops(glcm, 'homogeneity')[0, 0]
    correlation = graycoprops(glcm, 'correlation')[0, 0]

    # ----- SHAPE FEATURES -----
    _, thresh = cv2.threshold(gray, 127, 255,
                              cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    contours, _ = cv2.findContours(thresh,
                                   cv2.RETR_EXTERNAL,
                                   cv2.CHAIN_APPROX_SIMPLE)

    if len(contours) > 0:
        cnt = max(contours, key=cv2.contourArea)
        area = cv2.contourArea(cnt)
        perimeter = cv2.arcLength(cnt, True)
        x, y, w, h = cv2.boundingRect(cnt)
        aspect_ratio = float(w) / h if h != 0 else 0
    else:
        area = 0
        perimeter = 0
        aspect_ratio = 0

    features = [
        mean[0], mean[1], mean[2],
        std[0], std[1], std[2],
        contrast, energy, homogeneity, correlation,
        area, perimeter, aspect_ratio
    ]

    return np.array(features).reshape(1, -1)


# -----------------------------
# Predict Function
# -----------------------------
def predict_image(image_path):

    # Step 1: YOLO detection
    results = yolo_model(image_path)

    if len(results[0].boxes) == 0:
        print("No medicine detected.")
        return

    # Take first detected box
    box = results[0].boxes.xyxy[0].cpu().numpy().astype(int)

    img = cv2.imread(image_path)
    crop = img[box[1]:box[3], box[0]:box[2]]

    # Step 2: Extract features
    features = extract_features(crop)

    # Step 3: Scale features
    features_scaled = scaler.transform(features)

    # Step 4: Predict
    prob = xgb_model.predict_proba(features_scaled)[0]

    prediction = 1 if prob[1] > 0.30 else 0
    confidence = prob[prediction]

    if prediction == 0:
        print("Prediction: AUTHENTIC")
    else:
        print("Prediction: COUNTERFEIT")

    print("Confidence score:", confidence)

predict_image("./ind_test/fake1.jpg")
# Out:
# image 1/1 d:\research papers\jenil_sir_project\Counterfeit_med_detection.v4i.yolov8\ind_test\fake1.jpg: 416x352 1 authentic, 41.4ms
# Speed: 2.0ms preprocess, 41.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 352)
# Prediction: AUTHENTIC
# Confidence score: 0.9891131
# c:\Users\HP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix

xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    scale_pos_weight=6,  # IMPORTANT (imbalance handling)
    random_state=42
)

xgb_model.fit(X_train_scaled, y_train)

y_pred = xgb_model.predict(X_test_scaled)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       119
#            1       0.76      0.79      0.77        61
#
#     accuracy                           0.84       180
#    macro avg       0.83      0.83      0.83       180
# weighted avg       0.85      0.84      0.85       180
#
# [[104  15]
#  [ 13  48]]

# %%
scale_pos_weight = 1443 / 222   # ≈ 6.5

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    scale_pos_weight=6.5,
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss'
)

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'n_estimators': [100, 200, 300, 500],
    'max_depth': [3, 5, 7, 10],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0],
    'gamma': [0, 0.1, 0.3, 0.5],
    'min_child_weight': [1, 3, 5]
}

search = RandomizedSearchCV(
    estimator=model,
    param_distributions=param_dist,
    n_iter=30,
    scoring='f1',   # IMPORTANT: focus on F1
    cv=5,
    verbose=2,
    n_jobs=-1
)

search.fit(X_train, y_train)

best_model = search.best_estimator_

# %%
y_probs = best_model.predict_proba(X_test)[:, 1]

import numpy as np
from sklearn.metrics import f1_score

best_thresh = 0
best_f1 = 0

for t in np.arange(0.1, 0.9, 0.05):
    y_pred = (y_probs > t).astype(int)
    f1 = f1_score(y_test, y_pred)
    
    if f1 > best_f1:
        best_f1 = f1
        best_thresh = t

print("Best Threshold:", best_thresh)

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = (y_probs > best_thresh).astype(int)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

# %%
from xgboost import XGBClassifier

# Calculate class weight
scale_pos_weight = 1443 / 222   # use your actual values

model = XGBClassifier(
    n_estimators=200,
    max_depth=5,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    scale_pos_weight=scale_pos_weight,  # IMPORTANT
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss'
)

# %%
model.fit(X_train, y_train)

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
